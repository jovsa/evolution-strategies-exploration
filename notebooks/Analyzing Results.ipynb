# %%
import pandas as pd
import os
import glob
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

pd.options.mode.chained_assignment = None  # default='warn'
pd.set_option('display.max_columns', 500)

# %%
# constants
RUN_SUMMARY_LOC = '../run_summaries/hyperparam_search'

# %%
all_results = pd.DataFrame()
for file_ in glob.glob(os.path.join(RUN_SUMMARY_LOC, '*.csv')):
    temp = pd.read_csv(file_)
    all_results = all_results.append(temp)

# %%
all_results = all_results.sort_values(['run_name', 
                                       'iteration', 
                                       'timestamp', 
                                       'accuracy_test', 
                                       'accuracy_val', 
                                       'accuracy_train'])

# %%
fig, ax = plt.subplots(figsize=(20,15))
sns.pointplot(x='iteration', y='accuracy_test', hue='run_name', data=all_results)
plt.ylabel('accuracy')
plt.title('Test accuracy per iteration')
plt.xlabel('Iteration')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20,15))
sns.pointplot(x='iteration', y='accuracy_val', hue='run_name', data=all_results)
plt.ylabel('accuracy')
plt.title('Validation accuracy per iteration')
plt.xlabel('Iteration')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20,15))
sns.pointplot(x='iteration', y='accuracy_train', hue='run_name', data=all_results)
plt.ylabel('accuracy')
plt.title('Train accuracy per iteration')
plt.xlabel('Iteration')
plt.show()

# %%
# plt.figure(figsize=(20,20))
# for i, j in enumerate(all_results.run_name.unique()):
#     curr = all_results[all_results['run_name']==j].reset_index()
#     plt.plot(curr.iteration, curr.accuracy_test, marker='o')
# plt.legend()
# plt.show()
